# %%
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow_datasets as tfds
import os
import nltk

# %%
df = tf.data.TFRecordDataset("/Users/amith/Documents/GitHub/kaggle/Petals to the Metal - Flower Classification on TPU/tpu-getting-started/tfrecords-jpeg-192x192/train/00-192x192-798.tfrec")

# %%
p = []
q = []
for i in df.as_numpy_iterator():
    q = list(i)
    p = i
    break

# %%
stri = ""
for i in q:
    stri += chr(i)

# %%
amith = "My name is Amith \n\t My sister's name is Ananya \n\t My friend's name is Hari Vadana"

# %%
token = nltk.RegexpTokenizer("[^\’\\’\\\n\r\t\b\f\v\0]")
t = token.tokenize(stri)

# %%
st = "".join(t)
print(st)
# Out:
# £id338ab7bacclass9ç¢imageÜ¢Ø¢Ô¢ÿØÿàJFIF,,ÿÛCÿÛCÿÀÀÀÿÄÿÄB!1"AQaq2#B¡±RÑ$3bÁrá%4CSðñÿÄÿÄ9!1A"Qa2q¡±#BÁÑð3áñR4bÿÚ?øaSªå£d¯E±û­´[ÆªÔVÞ¥Ôm=(àèjÃKþTE¬×qJ[O#¦Î·ÓÂä¾¡ÜÕp¦ªu'TWÉÚ¬qöÖxbùBÅK+{ÅÄ¡gy9Éï§- îµ5W=kñËÏÑÊØ ð¹·n°ÎhïÅ+jdzNþ\gÐãCñ©ªâÓéÊ.ZÓpÏ9PmSVø¨$º@8G?H×Da/0ÏÓió+=µsrP\íG(Z£CðÐRî4ñýVÁU9Ç]ùfÏa§b]-ÝmsyCgÁZsÇ¨Òñ'CJ®;sCPËjÇæ¿>esÿgÃõ[yÈOTÜðîÉ)[jOçA¤úìuYte¡(UTÄN(K_%C¾±­Ã²V ÔäÒKìÅ9CÍìÝS©Jpé6+`-øp!_Ì=u*sáêjáP­·J¬xqPv(è5³|Ç).:¸E¶Í¥p]ñÓ658²Èyóµ {ä÷ÓI*"ã(Ø®÷jbÙ°?¦TYãí5öRAáý=´ÍÕoÉãÒî»1kd/çë©HQËç¾õrµgRáb°¥Êf2Ò°¡ÎZì¬@s*3Ko¼ãí©V±ÙblUjRa8°êHúèSÅä$¸d'ÅÐ´NÍV´Vß¤´ßUªòZÃÂ)`ÛtwTnÇæXÓOÄHî\±]½<4ôèA9%)sAaÝb~ÜX®>òváxûiøysRí*[¤ÙIC±ãî]H±[2Ù]Aé¼õ2y!¿SmÈæ¡êÉRi·-Ê¸cÒYJyånõ@¨òÀJÂÒSí¥=O^XJCÉÝàF5vÝµ%­àìd°¥'ëÆ¥)FNIJQQê 2gÊÇOËØÑ%jWT×ªPEN­1¶Ò*HÐZÆìÀ´_9v{Kð¨u·yã¨qï ºà¸-*^Êê%x°¸£æ>~;ÊÜ{ï§u-¢ùwgöi³êl¹>8ûê¨×pN¹ú_q4y¤ÎÌðF¤)ê¢Ø%¸ÂrU£>±"³)þºá(r¯,;ÎÈ¼.1â§rZæ+Ð}tÖª©ÌfåNËÝõÔ:¥z8¦³1¡6rÚ6æ?öì4Úfjvå8k<»¥ìºÒ`ÉØôßá¨`§vF¥ÙQ×+ì
# ...

# %%
stri.split("id","class")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 stri.split("id","class")
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
image_description = {
    "id" : tf.io.FixedLenFeature([],tf.string),
    "class" : tf.io.FixedLenFeature([],tf.string),
    "image": tf.io.FixedLenFeature([],tf.int64),
}

# %%
y = lambda x: tf.io.parse_single_example(x,image_description)

# %%
img = df.map(y)

# %%
img
# Out:
# <_MapDataset element_spec={'class': TensorSpec(shape=(), dtype=tf.string, name=None), 'id': TensorSpec(shape=(), dtype=tf.string, name=None), 'image': TensorSpec(shape=(), dtype=tf.int64, name=None)}>

# %%
img.element_spec["image"]
# Out:
# TensorSpec(shape=(), dtype=tf.int64, name=None)

# %%
img.element_spec["image"]
# Out:
# TensorSpec(shape=(), dtype=tf.int64, name=None)

# %%
img.element_spec["image"].experimental_from_proto()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 img.element_spec["image"].experimental_from_proto()
#
# TypeError: TensorSpec.experimental_from_proto() missing 1 required positional argument: 'proto'

# %%
for i,j in img.image.take(10):
    print(i.numpy())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 for i,j in img.image.take(10):
#       2     print(i.numpy())
#
# AttributeError: '_MapDataset' object has no attribute 'image'
